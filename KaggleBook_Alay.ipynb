# %%
import numpy as np
import pandas as pd
import googletrans

# %%
sales = pd.read_csv("sales_train.csv")
shops = pd.read_csv("shops.csv")
items = pd.read_csv("items.csv")
item_categories = pd.read_csv("item_categories.csv")
test = pd.read_csv("test.csv")

# %%
sales.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
shops.head()
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4

# %%
item_categories.head()
# Out:
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4

# %%
test.head()
# Out:
#    ID  shop_id  item_id
# 0   0        5     5037
# 1   1        5     5320
# 2   2        5     5233
# 3   3        5     5232
# 4   4        5     5268

# %%
import requests

def translate(x, key, src='ru', dest='en'):
    url = 'https://translate.yandex.net/api/v1.5/tr.json/translate'
    params = dict(
        key=key,
        lang=src+'-'+dest
    )
    dlen = len(x)
    counter = 0
    translated_text = []
    while dlen > 0:
        payload = {'text': x[counter:counter+100]}
        response = requests.post(url=url, params=params, data=payload)
        try :
            result = response.json()['text']
#             print(result)
            translated_text.extend(result)        
            dlen -= 100
            counter += 100
        except:
            print(response)
            sys.exit(1)
        print("Current progress: ", np.round(min(counter, len(x))/len(x)*100,2),"%")
#     print(translated_text)        
    dictionary = dict(zip(x, translated_text))
    return([dictionary.get(item, item) for item in x])

# %%
len(item_categories)
# Out:
# 84

# %%
item_categories['item_category_name_en'] = translate(item_categories['item_category_name'], "trnsl.1.1.20200226T053912Z.6c5aa1bee982cb25.fdc351c35d2299d71d5209e28c7f82add4b6529b")
item_categories.sample(10)
# Out:
# Current progress:  100.0 %
#                         item_category_name  item_category_id  \
# 25               Игры - Аксессуары для игр                25
# 59              Музыка - Музыкальное видео                59
# 0                  PC - Гарнитуры/Наушники                 0
# 39                       Кино - Blu-Ray 4K                39
# 16              Игровые консоли - XBOX ONE                16
# 51       Книги - Познавательная литература                51
# 83                        Элементы питания                83
# 72                       Подарки - Фигурки                72
# 65  Подарки - Настольные игры (компактные)                65
# 44              Книги - Аудиокниги (Цифра)                44
#
#              item_category_name_en
# 25     Games Accessories for games
# 59            Music - Music videos
# 0           PC Headsets/Headphones
# 39              Movie - Blu-Ray 4K
# 16       Gaming console - XBOX ONE
# 51  Books - Informative literature
# ...

# %%
item_categories_en = item_categories.drop('item_category_name', axis=1)
item_categories_en.columns = [["item_category_id", "item_category_name"]]
item_categories_en.head()
# Out:
#   item_category_id      item_category_name
# 0                0  PC Headsets/Headphones
# 1                1       Accessories - PS2
# 2                2       Accessories - PS3
# 3                3       Accessories - PS4
# 4                4       Accessories - PSP

# %%
# item_categories_en = item_categories[:,2:]
# item_categories_en.columns = [["item_category_id", "item_category_name"]]
# item_categories_en.head()

# %%
len(items)
# Out:
# 22170

# %%
items.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40

# %%
items['item_name_en'] = translate(items['item_name'], "trnsl.1.1.20200226T053912Z.6c5aa1bee982cb25.fdc351c35d2299d71d5209e28c7f82add4b6529b")
items.sample(10)
# Out:
# Current progress:  0.45 %
# Current progress:  0.9 %
# Current progress:  1.35 %
# Current progress:  1.8 %
# Current progress:  2.26 %
# Current progress:  2.71 %
# Current progress:  3.16 %
# Current progress:  3.61 %
# Current progress:  4.06 %
# Current progress:  4.51 %
# Current progress:  4.96 %
# Current progress:  5.41 %
# Current progress:  5.86 %
# Current progress:  6.31 %
# Current progress:  6.77 %
# Current progress:  7.22 %
# Current progress:  7.67 %
# Current progress:  8.12 %
# Current progress:  8.57 %
# Current progress:  9.02 %
# Current progress:  9.47 %
# Current progress:  9.92 %
# Current progress:  10.37 %
# Current progress:  10.83 %
# Current progress:  11.28 %
# Current progress:  11.73 %
# Current progress:  12.18 %
# Current progress:  12.63 %
# Current progress:  13.08 %
# Current progress:  13.53 %
# Current progress:  13.98 %
# Current progress:  14.43 %
# Current progress:  14.88 %
# Current progress:  15.34 %
# Current progress:  15.79 %
# ...

# %%
len(shops)
# Out:
# 60

# %%
shops.head()
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4

# %%
shops['shop_name_en'] = translate(shops['shop_name'], "trnsl.1.1.20200226T053912Z.6c5aa1bee982cb25.fdc351c35d2299d71d5209e28c7f82add4b6529b")
shops.sample(10)
# Out:
# Current progress:  100.0 %
#                          shop_name  shop_id  \
# 42          СПб ТК "Невский Центр"       42
# 1    !Якутск ТЦ "Центральный" фран        1
# 2                 Адыгея ТЦ "Мега"        2
# 16                Коломна ТЦ "Рио"       16
# 22              Москва Магазин С21       22
# 3   Балашиха ТРК "Октябрь-Киномир"        3
# 25             Москва ТРК "Атриум"       25
# 48    Томск ТРЦ "Изумрудный Город"       48
# 38                  Омск ТЦ "Мега"       38
# 8     Воронеж ТРЦ Сити-Парк "Град"        8
#
#                                  shop_name_en
# 42                     SPb TC "Nevsky Center"
# 1                 !Yakutsk TTS "Central" Fran
# 2               Adygea shopping center "Mega"
# 16              Kolomna shopping center "Rio"
# 22                            Moscow Shop C21
# 3            Balashikha TRK "October-Kinomir"
# 25                        Moscow TRK "atrium"
# 48       Tomsk shopping center "emerald City"
# ...

# %% [markdown]
# ### Merging datasets to create a master dataframe

# %%
del(master_df)

# %%
master_df = pd.merge(sales, shops, on="shop_id")
master_df.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  02.01.2013               0       59    22154       999.0           1.0
# 1  10.01.2013               0       59    22151       399.0           1.0
# 2  04.01.2013               0       59     5603       699.0           1.0
# 3  19.01.2013               0       59     5587       199.0           2.0
# 4  31.01.2013               0       59     5613      5571.0           1.0
#
#                 shop_name                        shop_name_en
# 0  Ярославль ТЦ "Альтаир"  Yaroslavl shopping center "Altair"
# 1  Ярославль ТЦ "Альтаир"  Yaroslavl shopping center "Altair"
# 2  Ярославль ТЦ "Альтаир"  Yaroslavl shopping center "Altair"
# 3  Ярославль ТЦ "Альтаир"  Yaroslavl shopping center "Altair"
# 4  Ярославль ТЦ "Альтаир"  Yaroslavl shopping center "Altair"

# %%
master_df = pd.merge(master_df, items, on="item_id")
master_df = pd.merge(master_df, item_categories, on="item_category_id")
master_df.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  02.01.2013               0       59    22154       999.0           1.0
# 1  02.01.2013               0       25    22154       999.0           1.0
# 2  03.01.2013               0       25    22154       999.0           1.0
# 3  20.01.2013               0       25    22154       999.0           1.0
# 4  23.01.2013               0       25    22154       999.0           1.0
#
#                 shop_name                        shop_name_en  \
# 0  Ярославль ТЦ "Альтаир"  Yaroslavl shopping center "Altair"
# 1     Москва ТРК "Атриум"                 Moscow TRK "atrium"
# 2     Москва ТРК "Атриум"                 Moscow TRK "atrium"
# 3     Москва ТРК "Атриум"                 Moscow TRK "atrium"
# 4     Москва ТРК "Атриум"                 Moscow TRK "atrium"
#
#            item_name  item_category_id          item_name_en  \
# 0  ЯВЛЕНИЕ 2012 (BD)                37  PHENOMENON 2012 (BD)
# ...

# %%
master_df = master_df.drop(labels=['shop_name', 'item_name', 'item_category_name'], axis=1)

# %%
master_df.head(10)
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  02.01.2013               0       59    22154       999.0           1.0
# 1  02.01.2013               0       25    22154       999.0           1.0
# 2  03.01.2013               0       25    22154       999.0           1.0
# 3  20.01.2013               0       25    22154       999.0           1.0
# 4  23.01.2013               0       25    22154       999.0           1.0
# 5  26.01.2013               0       25    22154       999.0           1.0
# 6  27.08.2015              31       25    22154       299.0           1.0
# 7  02.09.2015              32       25    22154       299.0           1.0
# 8  23.01.2013               0       24    22154       999.0           1.0
# 9  10.10.2015              33       24    22154       299.0           1.0
#
#                             shop_name  item_category_id             item_name  \
# ...

# %%
master_df=master_df.rename(columns = {'shop_name_en':'shop_name',
                                      'item_name_en':'item_name',
                                      'item_category_name_en':'item_category_name'})

# %%
master_df.sample(10)
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 1826753  17.03.2014              14       12    19408      1399.0
# 1593673  30.04.2014              15        5     3101       399.0
# 1165419  23.01.2013               0       29     3851       899.0
# 2343765  04.09.2014              20        6    14881       499.0
# 756137   26.08.2013               7       44    21883       149.0
# 461004   07.10.2013               9       44    12600       149.0
# 984119   19.07.2013               6       31     7739       499.0
# 770763   10.01.2015              24       14     5573       449.0
# 585310   27.10.2014              21       22    10511       399.0
# 1312711  27.01.2015              24       46     5037      2599.0
#
#          item_cnt_day                                        shop_name  \
# 1826753           1.0                           Online store emergency
# 1593673           1.0              Vologda shopping center "Marmalade"
# ...

# %%
master_df.to_csv('master_df.csv', sep=',', index= False, header= True)
